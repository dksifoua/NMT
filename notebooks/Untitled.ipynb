# %%
import os

# %%
os.getcwd()
# Out:
# '/notebooks/NMT/notebooks'

# %%
os.chdir('../')

# %%
os.getcwd()
# Out:
# '/notebooks/NMT'

# %%
# !python -m scripts.train --model=SeqToSeqLSTM
# Out:
# /usr/lib/python3.6/runpy.py:125: RuntimeWarning: 'scripts.train' found in sys.modules after import of package 'scripts', but prior to execution of 'scripts.train'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2020-09-08 01:09:44,860 - INFO - Device: cuda
# 2020-09-08 01:09:44,867 - INFO - Load Fields
# 2020-09-08 01:10:02,253 - INFO - Init the model
# 2020-09-08 01:10:05,005 - INFO - SeqToSeqLSTM(
#   (encoder): EncoderLayerLSTM(
#     (embeddings): Embedding(12097, 300)
#     (lstm): LSTM(300, 256, num_layers=2, dropout=0.25)
#   )
#   (decoder): DecoderLayerLSTM(
#     (embedding): Embedding(9419, 300)
#     (lstm): LSTM(300, 256, num_layers=2, dropout=0.25)
#     (fc): Linear(in_features=256, out_features=9419, bias=True)
#   )
# )
# 2020-09-08 01:10:05,005 - INFO - Number of parameters of the model: 11,070,939
# 2020-09-08 01:10:05,006 - INFO - Init the optimizer
# 2020-09-08 01:10:05,006 - INFO - Load datasets
# ...
